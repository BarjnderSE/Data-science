# %%
from sklearn.datasets import fetch_olivetti_faces
import matplotlib.pyplot as plt

# Load dataset
faces = fetch_olivetti_faces()
X, y = faces.data, faces.target

# Display a few images with their labels
fig, axes = plt.subplots(1, 5, figsize=(10, 5))
for i, ax in enumerate(axes):
    ax.imshow(faces.images[i], cmap="gray")
    ax.set_title(f"Label: {y[i]}")
    ax.axis("off")
plt.tight_layout()
plt.show()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\Owner\scikit_learn_data

# %%
from sklearn.model_selection import train_test_split

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print dataset shapes
print(f"Training set shape: {X_train.shape}")
print(f"Testing set shape: {X_test.shape}")
# Out:
# Training set shape: (280, 4096)
# Testing set shape: (120, 4096)

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize and train Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Display detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.83
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       1.00      1.00      1.00         4
#            2       0.40      1.00      0.57         2
#            3       1.00      1.00      1.00         4
#            4       0.67      0.67      0.67         3
#            5       0.75      1.00      0.86         3
#            6       1.00      1.00      1.00         3
#            7       1.00      0.25      0.40         8
#            8       0.67      1.00      0.80         2
#            9       1.00      1.00      1.00         3
#           10       0.60      1.00      0.75         3
#           11       1.00      0.80      0.89         5
#           12       1.00      1.00      1.00         2
#           13       1.00      0.67      0.80         3
#           14       1.00      1.00      1.00         3
#           15       0.75      1.00      0.86         3
# ...

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# Compute metrics
precision = precision_score(y_test, y_pred, average="weighted")
recall = recall_score(y_test, y_pred, average="weighted")
f1 = f1_score(y_test, y_pred, average="weighted")

# Bar chart
metrics = {"Accuracy": accuracy, "Precision": precision, "Recall": recall, "F1 Score": f1}
plt.figure(figsize=(8, 5))
plt.bar(metrics.keys(), metrics.values(), color=["blue", "green", "orange", "red"])
plt.ylim(0, 1.1)
plt.title("Model Performance Metrics")
plt.xlabel("Metrics")
plt.ylabel("Score")
plt.show()
# Out:
# c:\Users\Owner\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Choose a random image from the test set for prediction
sample_index = 10  # You can change this index to test different images
sample_image = X_test[sample_index].reshape(1, -1)  # Reshape to 1D array for prediction

# Predict the label of the selected image
predicted_label = clf.predict(sample_image)[0]

# Display the image and the predicted label
plt.imshow(X_test[sample_index].reshape(64, 64), cmap="gray")
plt.title(f"Predicted Label: {predicted_label}")
plt.axis("off")
plt.show()

# Optionally, you can print the actual label to compare
actual_label = y_test[sample_index]
print(f"Actual Label: {actual_label}")
# Out:
# Actual Label: 0

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# Load the Digits dataset
digits = load_digits()
X, y = digits.data, digits.target

# Display a few images with their labels
fig, axes = plt.subplots(1, 5, figsize=(10, 5))
for i, ax in enumerate(axes):
    ax.imshow(digits.images[i], cmap="gray")
    ax.set_title(f"Label: {y[i]}")
    ax.axis("off")
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Display detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.98
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        53
#            1       0.96      1.00      0.98        50
#            2       1.00      1.00      1.00        47
#            3       0.98      0.96      0.97        54
#            4       0.97      1.00      0.98        60
#            5       0.97      0.95      0.96        66
#            6       0.98      0.98      0.98        53
#            7       0.98      0.98      0.98        55
#            8       0.95      0.95      0.95        43
#            9       0.97      0.95      0.96        59
#
#     accuracy                           0.98       540
#    macro avg       0.98      0.98      0.98       540
# weighted avg       0.98      0.98      0.98       540

# %%
# Choose a random image from the test set for prediction
sample_index = 0  # You can change this index to test different images
sample_image = X_test[sample_index].reshape(1, -1)  # Reshape to 1D array for prediction

# Predict the label of the selected image
predicted_label = clf.predict(sample_image)[0]

# Display the image and the predicted label
plt.imshow(X_test[sample_index].reshape(8, 8), cmap="gray")
plt.title(f"Predicted Label: {predicted_label}")
plt.axis("off")
plt.show()

# Optionally, you can print the actual label to compare
actual_label = y_test[sample_index]
print(f"Actual Label: {actual_label}")
# Out:
# Actual Label: 6
